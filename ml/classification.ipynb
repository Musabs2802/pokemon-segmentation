# %%
import pandas as pd
from pycaret.datasets import get_data
from pycaret.classification import *
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("../../output/clustered_data.csv")
df
# Out:
#       Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0      Grass  Poison    318  45      49       49       65       65     45
# 1      Grass  Poison    405  60      62       63       80       80     60
# 2      Grass  Poison    525  80      82       83      100      100     80
# 3      Grass  Poison    625  80     100      123      122      120     80
# 4       Fire     NaN    309  39      52       43       60       50     65
# ..       ...     ...    ...  ..     ...      ...      ...      ...    ...
# 795     Rock   Fairy    600  50     100      150      100      150     50
# 796     Rock   Fairy    700  50     160      110      160      110    110
# 797  Psychic   Ghost    600  80     110       60      150      130     70
# 798  Psychic    Dark    680  80     160       60      170      130     80
# 799     Fire   Water    600  80     110      120      130       90     70
#
#      Generation  Legendary    Cluster
# 0             1          0  Cluster 0
# 1             1          0  Cluster 3
# 2             1          0  Cluster 1
# 3             1          0  Cluster 2
# 4             1          0  Cluster 0
# ..          ...        ...        ...
# 795           6          1  Cluster 2
# 796           6          1  Cluster 2
# 797           6          1  Cluster 2
# 798           6          1  Cluster 2
# 799           6          1  Cluster 2
#
# [800 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Cluster'],
#       dtype='object')

# %%
setup(data=df, target="Cluster")
# Out:
# <style type="text/css">
# #T_7b577_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7b577">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b577_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7b577_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b577_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7b577_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_7b577_row0_col1" class="data row0 col1" >5007</td>
#     </tr>
#     <tr>
#       <th id="T_7b577_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7b577_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7b577_row1_col1" class="data row1 col1" >Cluster</td>
#     </tr>
#     <tr>
#       <th id="T_7b577_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7b577_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_7b577_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_7b577_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7b577_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_7b577_row3_col1" class="data row3 col1" >Cluster 0: 0, Cluster 1: 1, Cluster 2: 2, Cluster 3: 3</td>
#     </tr>
#     <tr>
#       <th id="T_7b577_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7b577_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_7b577_row4_col1" class="data row4 col1" >(800, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_7b577_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7b577_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_7b577_row5_col1" class="data row5 col1" >(800, 46)</td>
#     </tr>
#     <tr>
#       <th id="T_7b577_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7b577_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_7b577_row6_col1" class="data row6 col1" >(560, 46)</td>
#     </tr>
#     <tr>
#       <th id="T_7b577_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7b577_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_7b577_row7_col1" class="data row7 col1" >(240, 46)</td>
#     </tr>
#     <tr>
#       <th id="T_7b577_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7b577_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_7b577_row8_col1" class="data row8 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_7b577_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7b577_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_7b577_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7b577_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7b577_row10_col0" class="data row10 col0" >Rows with missing values</td>
#       <td id="T_7b577_row10_col1" class="data row10 col1" >48.2%</td>
#     </tr>
#     <tr>
#       <th id="T_7b577_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7b577_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_7b577_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_7b577_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7b577_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_7b577_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_7b577_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7b577_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_7b577_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_7b577_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7b577_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_7b577_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_7b577_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7b577_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_7b577_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_7b577_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7b577_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_7b577_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7b577_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7b577_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_7b577_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_7b577_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7b577_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_7b577_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_7b577_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_7b577_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_7b577_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_7b577_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_7b577_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_7b577_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7b577_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_7b577_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_7b577_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7b577_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_7b577_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_7b577_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_7b577_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_7b577_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_7b577_row23_col1" class="data row23 col1" >6174</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_1b017 th {
#   text-align: left;
# }
# #T_1b017_row0_col0, #T_1b017_row1_col0, #T_1b017_row2_col0, #T_1b017_row2_col1, #T_1b017_row2_col3, #T_1b017_row2_col4, #T_1b017_row2_col5, #T_1b017_row2_col6, #T_1b017_row2_col7, #T_1b017_row3_col0, #T_1b017_row3_col1, #T_1b017_row3_col3, #T_1b017_row3_col4, #T_1b017_row3_col5, #T_1b017_row3_col6, #T_1b017_row3_col7, #T_1b017_row4_col0, #T_1b017_row4_col1, #T_1b017_row4_col3, #T_1b017_row4_col4, #T_1b017_row4_col5, #T_1b017_row4_col6, #T_1b017_row4_col7, #T_1b017_row5_col0, #T_1b017_row5_col1, #T_1b017_row5_col3, #T_1b017_row5_col4, #T_1b017_row5_col5, #T_1b017_row5_col6, #T_1b017_row5_col7, #T_1b017_row6_col0, #T_1b017_row6_col1, #T_1b017_row6_col3, #T_1b017_row6_col4, #T_1b017_row6_col5, #T_1b017_row6_col6, #T_1b017_row6_col7, #T_1b017_row7_col0, #T_1b017_row7_col1, #T_1b017_row7_col3, #T_1b017_row7_col4, #T_1b017_row7_col5, #T_1b017_row7_col6, #T_1b017_row7_col7, #T_1b017_row8_col0, #T_1b017_row8_col1, #T_1b017_row8_col3, #T_1b017_row8_col4, #T_1b017_row8_col5, #T_1b017_row8_col6, #T_1b017_row8_col7, #T_1b017_row9_col0, #T_1b017_row9_col1, #T_1b017_row9_col3, #T_1b017_row9_col4, #T_1b017_row9_col5, #T_1b017_row9_col6, #T_1b017_row9_col7, #T_1b017_row10_col0, #T_1b017_row10_col1, #T_1b017_row10_col3, #T_1b017_row10_col4, #T_1b017_row10_col5, #T_1b017_row10_col6, #T_1b017_row10_col7, #T_1b017_row11_col0, #T_1b017_row11_col1, #T_1b017_row11_col3, #T_1b017_row11_col4, #T_1b017_row11_col5, #T_1b017_row11_col6, #T_1b017_row11_col7, #T_1b017_row12_col0, #T_1b017_row12_col1, #T_1b017_row12_col3, #T_1b017_row12_col4, #T_1b017_row12_col5, #T_1b017_row12_col6, #T_1b017_row12_col7, #T_1b017_row13_col0, #T_1b017_row13_col1, #T_1b017_row13_col3, #T_1b017_row13_col4, #T_1b017_row13_col5, #T_1b017_row13_col6, #T_1b017_row13_col7 {
#   text-align: left;
# }
# #T_1b017_row0_col1, #T_1b017_row0_col2, #T_1b017_row0_col3, #T_1b017_row0_col4, #T_1b017_row0_col5, #T_1b017_row0_col6, #T_1b017_row0_col7, #T_1b017_row1_col1, #T_1b017_row1_col2, #T_1b017_row1_col3, #T_1b017_row1_col4, #T_1b017_row1_col5, #T_1b017_row1_col6, #T_1b017_row1_col7, #T_1b017_row2_col2, #T_1b017_row3_col2, #T_1b017_row4_col2, #T_1b017_row5_col2, #T_1b017_row6_col2, #T_1b017_row7_col2, #T_1b017_row8_col2, #T_1b017_row9_col2, #T_1b017_row10_col2, #T_1b017_row11_col2, #T_1b017_row12_col2, #T_1b017_row13_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_1b017_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_1b017_row1_col8, #T_1b017_row2_col8, #T_1b017_row3_col8, #T_1b017_row4_col8, #T_1b017_row5_col8, #T_1b017_row6_col8, #T_1b017_row7_col8, #T_1b017_row8_col8, #T_1b017_row9_col8, #T_1b017_row10_col8, #T_1b017_row11_col8, #T_1b017_row12_col8, #T_1b017_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_1b017">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b017_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1b017_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_1b017_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_1b017_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_1b017_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_1b017_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_1b017_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_1b017_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_1b017_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b017_level0_row0" class="row_heading level0 row0" >dt</th>
#       <td id="T_1b017_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_1b017_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_1b017_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_1b017_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_1b017_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_1b017_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_1b017_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_1b017_row0_col7" class="data row0 col7" >1.0000</td>
#       <td id="T_1b017_row0_col8" class="data row0 col8" >0.1120</td>
#     </tr>
#     <tr>
#       <th id="T_1b017_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_1b017_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_1b017_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_1b017_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_1b017_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_1b017_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_1b017_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_1b017_row1_col6" class="data row1 col6" >1.0000</td>
#       <td id="T_1b017_row1_col7" class="data row1 col7" >1.0000</td>
#       <td id="T_1b017_row1_col8" class="data row1 col8" >0.8340</td>
#     </tr>
#     <tr>
#       <th id="T_1b017_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_1b017_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_1b017_row2_col1" class="data row2 col1" >0.9982</td>
#       <td id="T_1b017_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_1b017_row2_col3" class="data row2 col3" >0.9982</td>
#       <td id="T_1b017_row2_col4" class="data row2 col4" >0.9983</td>
#       <td id="T_1b017_row2_col5" class="data row2 col5" >0.9982</td>
#       <td id="T_1b017_row2_col6" class="data row2 col6" >0.9975</td>
#       <td id="T_1b017_row2_col7" class="data row2 col7" >0.9976</td>
#       <td id="T_1b017_row2_col8" class="data row2 col8" >1.2310</td>
#     </tr>
#     <tr>
#       <th id="T_1b017_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_1b017_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_1b017_row3_col1" class="data row3 col1" >0.9946</td>
#       <td id="T_1b017_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_1b017_row3_col3" class="data row3 col3" >0.9946</td>
#       <td id="T_1b017_row3_col4" class="data row3 col4" >0.9949</td>
#       <td id="T_1b017_row3_col5" class="data row3 col5" >0.9946</td>
#       <td id="T_1b017_row3_col6" class="data row3 col6" >0.9926</td>
#       <td id="T_1b017_row3_col7" class="data row3 col7" >0.9927</td>
#       <td id="T_1b017_row3_col8" class="data row3 col8" >0.3660</td>
#     </tr>
#     <tr>
#       <th id="T_1b017_level0_row4" class="row_heading level0 row4" >knn</th>
#       <td id="T_1b017_row4_col0" class="data row4 col0" >K Neighbors Classifier</td>
#       <td id="T_1b017_row4_col1" class="data row4 col1" >0.9714</td>
#       <td id="T_1b017_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_1b017_row4_col3" class="data row4 col3" >0.9714</td>
#       <td id="T_1b017_row4_col4" class="data row4 col4" >0.9727</td>
#       <td id="T_1b017_row4_col5" class="data row4 col5" >0.9711</td>
#       <td id="T_1b017_row4_col6" class="data row4 col6" >0.9604</td>
#       <td id="T_1b017_row4_col7" class="data row4 col7" >0.9610</td>
#       <td id="T_1b017_row4_col8" class="data row4 col8" >0.8890</td>
#     </tr>
#     <tr>
#       <th id="T_1b017_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_1b017_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_1b017_row5_col1" class="data row5 col1" >0.9357</td>
#       <td id="T_1b017_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_1b017_row5_col3" class="data row5 col3" >0.9357</td>
#       <td id="T_1b017_row5_col4" class="data row5 col4" >0.9418</td>
#       <td id="T_1b017_row5_col5" class="data row5 col5" >0.9342</td>
#       <td id="T_1b017_row5_col6" class="data row5 col6" >0.9099</td>
#       <td id="T_1b017_row5_col7" class="data row5 col7" >0.9129</td>

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predict_model(best_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f1e3f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1e3f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f1e3f_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_f1e3f_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_f1e3f_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_f1e3f_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_f1e3f_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_f1e3f_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_f1e3f_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1e3f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f1e3f_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_f1e3f_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_f1e3f_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_f1e3f_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_f1e3f_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_f1e3f_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_f1e3f_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_f1e3f_row0_col7" class="data row0 col7" >1.0000</td>
#     </tr>
#   </tbody>
# </table>
#        Type 1    Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 94      Water       Ice    475  90      70       80       70       95     70
# 770     Fairy       NaN    525  95      65       65      110      130     60
# 150      Rock     Water    495  70      60      125      115       70     55
# 554     Grass       NaN    308  45      45       55       45       55     63
# 88   Electric     Steel    325  25      35       70       95       55     45
# ..        ...       ...    ...  ..     ...      ...      ...      ...    ...
# 783     Ghost     Grass    335  59      66       70       44       55     41
# 620      Dark  Fighting    348  50      75       70       35       70     48
# 638   Psychic       NaN    290  45      30       40      105       50     20
# 194  Electric       NaN    365  70      55       55       80       60     45
# 758      Rock     Water    306  42      52       67       39       56     50
#
#      Generation  Legendary    Cluster prediction_label  prediction_score
# 94            1          0  Cluster 1        Cluster 1               1.0
# 770           6          0  Cluster 1        Cluster 1               1.0
# 150           1          0  Cluster 1        Cluster 1               1.0
# 554           5          0  Cluster 0        Cluster 0               1.0
# 88            1          0  Cluster 0        Cluster 0               1.0
# ..          ...        ...        ...              ...               ...
# 783           6          0  Cluster 0        Cluster 0               1.0
# 620           5          0  Cluster 3        Cluster 3               1.0
# 638           5          0  Cluster 0        Cluster 0               1.0
# 194           2          0  Cluster 3        Cluster 3               1.0
# 758           6          0  Cluster 0        Cluster 0               1.0
#
# [240 rows x 14 columns]

# %%
save_model(best_model,'classification_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Total', 'HP', 'Attack', 'Defense',
#                                               'Sp. Atk', 'Sp. Def', 'Speed',
#                                               'Generation', 'Legendary'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,...
#                                      transformer=CleanColumnNames(match='[\\]\\[\\,\\{\\}\\"\\:]+'))),
#                  ('trained_model',
#                   DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                          criterion='gini', max_depth=None,
#                                          max_features=None, max_leaf_nodes=None,
#                                          min_impurity_decrease=0.0,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          monotonic_cst=None, random_state=5007,
#                                          splitter='best'))],
#           verbose=False),
#  'classification_model.pkl')
